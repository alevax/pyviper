# %%
from libs.pyther_classes import *
from libs.pyther_fn import *

import pandas as pd

# %% [markdown]
# ## Load test dataset

# %%
path = 'E:/lab/code_experiment/viper_py/'
testset = anndata.read_csv(path + 'Chan_HMP_subset_1000.csv').T
hmp_16 = load_interactome_from_tsv(path +'HMP_16_pruned.tsv', 'HMP_16')
hmp_19 =  load_interactome_from_tsv(path +'HMP_19_pruned.tsv', 'HMP_19')

# %% [markdown]
# ## Run Pyther(metaViper)

# %%
test = pyther(testset,[hmp_16, hmp_19])
test
# Out:
# Computing the association scores
# Computing regulons enrichment with aREA
# mvws = 1
# e:\lab\pyther\libs\pyther_fn.py:419: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['value'] = np.sum(nes*ws,axis =1)/np.sum(ws,axis =1)
# gene              A2M      AAK1      AATK     ABCA1     ABCA7     ABCC8  \
# index
# HMP04_V1066  1.496446 -2.403667  0.466714  1.087017 -0.676714 -3.666005
# HMP04_V1073 -2.314850  4.556739  1.423485  2.162607  1.083814 -1.265090
# HMP04_V1081  1.908105 -1.658602  0.854304 -0.589970 -0.599736 -3.132715
# HMP04_V1105 -4.149835 -3.109896  0.110662 -1.313440  0.414985  2.792890
# HMP04_V113  -1.952966 -1.403143  1.808711  1.038895  1.858052 -2.107963
# ...               ...       ...       ...       ...       ...       ...
# HMP25_V82   -4.531072  4.835715 -0.741467 -3.694489  1.515604  0.809738
# HMP25_V895  -4.944954  6.629766  0.606302 -3.780378  1.756013  1.499121
# HMP25_V929  -5.858626  7.173600  0.683089 -2.517798  2.003317  2.150989
# HMP26_V144  -4.347955  5.036337 -0.696720 -2.747658  1.468427 -0.285178
# HMP26_V512  -6.197134  6.141563 -0.556056  2.231014  2.159490  0.786089
#
# gene            ABHD2      ABI2      ABL1      ABL2  ...   ZSCAN29   ZSCAN30  \
# index                                                ...
# HMP04_V1066 -1.363975  0.715420 -1.437227 -1.818407  ... -1.639080 -3.572496
# HMP04_V1073 -4.168391  2.083448  1.605003  2.104669  ...  0.983952  1.123152
# HMP04_V1081  1.122533  0.660228 -3.026176 -1.892523  ... -2.577626 -2.554684
# HMP04_V1105  1.960786 -1.825244 -1.662785 -1.489310  ... -2.500234 -2.208571
# HMP04_V113   0.823476 -0.977166 -1.833119 -1.507517  ... -3.180338 -1.289460
# ...               ...       ...       ...       ...  ...       ...       ...
# HMP25_V82   -5.063787  3.926893  1.448492  0.853631  ... -0.306150  1.187558
# HMP25_V895  -7.030221  4.149097  2.846978  0.244202  ...  0.492036  1.325617
# HMP25_V929  -9.460258  7.344010  1.728613  1.538407  ...  1.315585  1.544767
# HMP26_V144  -3.810336  0.869621  0.827529  2.052376  ...  0.624243  1.292653
# HMP26_V512  -6.117536  3.721078  0.782432  1.307718  ...  0.372245  1.599695
#
# gene          ZSCAN31   ZSCAN32   ZSCAN5A    ZSCAN9      ZW10      ZXDA  \
# index
# HMP04_V1066 -3.136234 -0.705952  0.260245  0.656403  1.111279  0.369879
# HMP04_V1073 -4.280963  1.435359 -1.058355 -0.735677  0.883861  0.707945
# HMP04_V1081 -1.352375 -0.611972 -2.053387 -0.851055  0.607204 -0.129083
# HMP04_V1105  2.116349 -0.762282 -1.011957 -1.207573 -0.041102  0.511082
# HMP04_V113   1.026656 -0.397012 -1.569440 -0.202422  0.831919  0.562832
# ...               ...       ...       ...       ...       ...       ...
# HMP25_V82   -3.840653  1.402553 -0.409815 -0.325752  1.556269  1.340565
# HMP25_V895  -6.560680  1.345209 -0.548472  0.037427  1.694912  1.179427
# HMP25_V929  -7.046071  1.433563  0.576493  0.190020  1.913766  1.179261
# HMP26_V144  -1.826103  1.481391  0.039742 -0.446338  1.539005  1.142396
# HMP26_V512  -4.376695  1.568331  0.984459  0.500960  2.062205  1.474934
#
# gene             ZXDC       ZYX
# index
# HMP04_V1066 -1.452101 -2.170714
# HMP04_V1073 -0.968392 -1.194070
# HMP04_V1081  1.402356 -1.734290
# HMP04_V1105 -2.807716 -2.287398
# HMP04_V113  -1.290890 -2.925942
# ...               ...       ...
# HMP25_V82   -2.571245 -0.398712
# HMP25_V895  -2.057126 -0.774549
# HMP25_V929   0.625259 -0.564043
# HMP26_V144  -1.292753 -0.008056
# HMP26_V512  -0.723683 -0.288040
#
# [1000 rows x 5089 columns]
